# %% [markdown]
# # Setting Tasks

# %% [markdown]
# *Tasks:*

# %%
import pandas as pd
import numpy as np

file_sci = 'scimagojr.xlsx'
file_ei = 'Energy Indicators.xls'


energy = pd.read_excel(file_ei)

energy


# def print_seasons():
#     print
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# ..          ...                                                ...
# 277         NaN                       … denotes no data available.
# 278         NaN                                                NaN
# 279         NaN                                     Data Quality:
# 280         NaN  The data are compiled primarily from the annua...
# 281         NaN  For more information, visit http://unstats.un....
#
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                     Environmental Indicators: Energy        NaN        NaN
# ...

# %% [markdown]
# # Section 2

# %% [markdown]
# # Task 2

# %%
words = [
    'Листя', 'зелене', ',', 'птахи', 'співають', ',', 'а', 'все', 'навіть', 'квітне', 'навкруги', '.'
]

signs = [',', '.', '!', '?']
sentence = ''

for i in range(len(words)):
    sentence += words[i]
    # First, check if this is not the last element, and only then check the next one
    if i < len(words) - 1 and words[i+1] not in signs:
        sentence += ' '

print(sentence)
# Out:
# Листя зелене, птахи співають, а все навіть квітне навкруги.

# %% [markdown]
# # Task 4
